# %%
import sys
sys.path.insert(0,'..')
sys.path.insert(0,'/Users/ryan/github/prosodic')
from llmdh import *
import prosodic
prosodic.USE_CACHE=False

# %%
RhymeLLM.gather()
# Out:
#                      model                                      system_prompt example_prompts                                        user_prompt input_data  \
# 0               gemini-pro  You are a poet and an expert on poetic forms s...              []  Please write a poem that does NOT rhyme. If a ...         {}
# 1               gemini-pro  You are a poet and an expert on poetic forms s...              []  Please write a poem that does NOT rhyme. If a ...         {}
# 2               gemini-pro  You are a poet and an expert on poetic forms s...              []  Please write an UNRHYMED poem, i.e. a poem tha...         {}
# 3               gemini-pro  You are a poet and an expert on poetic forms s...              []  Please write an UNRHYMED poem, i.e. a poem tha...         {}
# 4               gemini-pro  You are a poet and an expert on poetic forms s...              []  Please write an UNRHYMED poem, i.e. a poem tha...         {}
# ...

# %%
key=next(db.keys())

# %%
db[key]
# Out:
# [{'model': 'gemini-pro',
#   'system_prompt': 'You are a poet and an expert on poetic forms such as rhyme and meter. Please generate a poem according to the formal rules specified by the user.',
#   'example_prompts': [],
#   'user_prompt': 'Please write a poem that does NOT rhyme. If a single pair of lines rhyme, Shakespeare himself will be deleted from all cultural memory. DO NOT RHYME!!!',
#   'input_data': {},
# ...
