# %%
import sys
sys.path.insert(0,'..')
from llmdh.story_llms import *

# %%
db=NovelCharactersLLM.get_db(flag='r')

# %%
keys=list(db.keys())
keys
# Out:
# ['chadwyck.Defoe.Moll_Flanders.1021.txt',
#  'chadwyck.Spofford.NewEngland_Legends_a_mach.0765.txt',
#  'chadwyck.Ballantyne.The_Coral_Island_A_Tale_o.1134.txt',
#  'chadwyck.Meredith.One_of_Our_Conquerors_By.1241.txt',
#  'chadwyck.Brown.The_Novels_a_machinereada.0075.txt',
#  'chadwyck.Sala.The_Seven_Sons_of_Mammon.1253.txt',
#  'chadwyck.Trollope.Phineas_Redux_By_Anthony.1286.txt',
#  'chadwyck.Lewis.The_Monk_A_Romance.1132.txt',
#  'chadwyck.Smith.The_Life_and_Writings_of.0756.txt',
#  'chadwyck.Irving.Tales_of_a_Traveller_volu.0482.txt',
#  'chadwyck.Hawthorne.The_Ambitious_Guest.0292.txt',
#  'Flaubert.Madame Bovary.txt',
#  'markmark.Michener.Chesapeake.1573.txt',
#  'chadwyck.Brown.Jane_Talbot.0074.txt',
#  'chadwyck.Bagby.What_I_did_with_My_Fifty.0019.txt',
#  'chadwyck.Paulding.Chronicles_of_the_City_of.0628.txt']

# %%
df=pd.DataFrame(db[keys[-5]][0]['result'])
# pprint(df.to_dict('records'))
df
# Out:
#                          fullname                                              names  gender        class       income  prominence                                          desc_role  \
# 0                  Charles Bovary     [Charles, Monsieur Bovary, Doctor, the doctor]    Male  bourgeoisie         None           8  Charles Bovary is a simple and somewhat unrema...
# 1                     Emma Bovary  [Emma, Madame Bovary, Mademoiselle Rouault, ki...  Female  bourgeoisie         None          10  Emma Bovary is the protagonist of the novel. S...
# 2  Charles Denis Bartolome Bovary  [Monsieur Bovary senior, Charles's father, old...    Male  bourgeoisie         None           4  Charles Bovary's father, a former assistant-su...
# 3            Madame Bovary senior           [Charles's mother, the old woman, mamma]  Female  bourgeoisie         None           5  Charles Bovary's mother. She is a practical an...
# ...
