# %%
import sys
sys.path.insert(0,'..')
from llmdh.story_llms import *

# %%
NovelRelationshipsLLM.gen_all()
# Out:
# ⎾ parsing all novels @ 2024-05-20 19:04:41,007
# ￨ iterating:   0%|          | 0/142 [00:00<?, ?it/s]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:04:48,889
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:04:48,890
# ￨ failed on markmark.Fitzgerald.Tender_is_the_Night.1442.txt. sleeping for 21s:   1%|          | 1/142 [00:28<1:07:53, 28.89s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:05:32,552
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:05:32,558
# ￨ failed on markmark.Clancy.Clear_and_Present_Danger.1391.txt. sleeping for 13s:   1%|▏         | 2/142 [01:04<1:16:43, 32.88s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:05:55,428
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:05:55,434
# ￨ failed on markmark.Grisham.The_Partner.1475.txt. sleeping for 8s:   2%|▏         | 3/142 [01:22<1:00:18, 26.03s/it]             The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:06:16,583
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:06:16,586
# ￨ failed on markmark.Lawrence.The_Rainbow.1549.txt. sleeping for 18s:   3%|▎         | 4/142 [01:53<1:04:30, 28.05s/it]First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:06:52,357
# Reparse failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:06:53,595
# ￨ failed on chadwyck.Hawthorne.TwiceTold_Tales.0329.txt. sleeping for 15s:   4%|▎         | 5/142 [02:27<1:08:57, 30.20s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:07:13,703
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:07:13,711
# ￨ failed on chadwyck.Thackeray.Lovel_the_Widower_By_W_M.1271.txt. sleeping for 23s:   4%|▍         | 6/142 [02:55<1:06:51, 29.49s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:07:58,423
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:07:58,425
# ￨ failed on Richardson.Pamela.Vol2.txt. sleeping for 12s:   5%|▍         | 7/142 [03:29<1:09:27, 30.87s/it]                          The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:08:30,059
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:08:30,060
# ￨ found 3 in Chaucer.Canterbury_Tales.02.Knights_Tale.txt. sleeping for 8s:   6%|▋         | 9/142 [04:28<1:07:08, 30.29s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:09:42,941
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:09:42,949
# ￨ failed on markmark.Ford.Parades_End.1446.txt. sleeping for 11s:   7%|▋         | 10/142 [05:12<1:16:34, 34.80s/it]         The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:10:01,809
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:10:01,816
# ￨ failed on markmark.Grisham.The_Street_Lawyer.1478.txt. sleeping for 8s:   8%|▊         | 11/142 [05:28<1:03:19, 29.01s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:10:15,263
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:10:15,266
# ￨ failed on markmark.Morrison.Jazz.1581.txt. sleeping for 18s:   8%|▊         | 12/142 [05:52<59:11, 27.32s/it]             First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:10:37,175
# Reparse failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:10:37,716
# ￨ failed on chadwyck.Hawthorne.The_Haunted_Mind_from_Twi.0304.txt. sleeping for 24s:   9%|▉         | 13/142 [06:20<59:28, 27.67s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:11:15,199
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:11:15,201
# ￨ failed on markmark.Auster.The_New_York_Trilogy.1350.txt. sleeping for 16s:  10%|▉         | 14/142 [06:50<1:00:10, 28.21s/it]      The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:11:42,664
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:11:42,665
# ￨ failed on markmark.McCarthy.Suttree.1568.txt. sleeping for 21s:  11%|█         | 15/142 [07:22<1:02:25, 29.49s/it]           First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:12:10,775
# Reparse failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:12:11,301
# ￨ failed on chadwyck.Brown.Amusements_Serious_and_Co.0936.txt. sleeping for 23s:  11%|█▏        | 16/142 [07:53<1:02:40, 29.84s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:12:38,043
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19
/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:39:37,019
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:39:37,022
# ￨ failed on markmark.Heinlein.Double_Star.1488.txt. sleeping for 19s:  51%|█████     | 72/142 [35:15<33:51, 29.02s/it]             First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:40:00,349
# Reparse failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:40:00,804
# ￨ failed on chadwyck.Hawthorne.Chippings_with_a_Chisel.0296.txt. sleeping for 23s:  51%|█████▏    | 73/142 [35:42<32:56, 28.65s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:40:31,639
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:40:31,642
# ￨ failed on markmark.Faulkner.The_Sound_and_the_Fury.1437.txt. sleeping for 14s:  52%|█████▏    | 74/142 [36:04<30:09, 26.61s/it]  The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:40:55,845
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:40:55,855
# ￨ failed on markmark.Grisham.The_Summons.1479.txt. sleeping for 22s:  53%|█████▎    | 75/142 [36:36<31:35, 28.29s/it]            The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:41:33,742
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:41:33,747
# ￨ failed on markmark.James.The_Golden_Bowl.1519.txt. sleeping for 19s:  54%|█████▎    | 76/142 [37:11<33:17, 30.27s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:41:56,797
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:41:56,800
# ￨ found 1 in Bible.Matthew.KJV.txt. sleeping for 21s:  55%|█████▍    | 78/142 [38:00<30:25, 28.53s/it]                 The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:42:46,121
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:42:46,125
# ￨ failed on Anon.Lazarillo.txt. sleeping for 23s:  56%|█████▌    | 79/142 [38:28<29:35, 28.19s/it]    First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:43:35,652
# fixed by second request @ 2024-05-20 19:43:37,200
# ￨ found 1 in Apuleius.Golden_Ass.txt. sleeping for 12s:  56%|█████▋    | 80/142 [39:08<32:49, 31.76s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:43:59,283
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:43:59,286
# ￨ failed on markmark.Pynchon.V.1600.txt. sleeping for 11s:  57%|█████▋    | 81/142 [39:29<29:02, 28.56s/it]The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:44:24,728
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:44:24,732
# ￨ failed on Franzen.Freedom.txt. sleeping for 13s:  58%|█████▊    | 82/142 [39:56<28:13, 28.22s/it]        The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked. @ 2024-05-20 19:44:47,400
# First failed: Expecting value: line 1 column 2 (char 1) @ 2024-05-20 19:44:47,406
# ￨ failed on Knausgaard.My Struggle.Book1.txt. sleeping for 22s:  58%|█████▊    | 83/142 [40:28<28:46, 29.26s/it]￨ KeyboardInterrupt  @ 2024-05-20 19:45:11,690
# ￨ failed on Knausgaard.My Struggle.Book1.txt. sleeping for 22s:  58%|█████▊    | 83/142 [40:30<28:47, 29.29s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 NovelRelationshipsLLM.gen_all()
#
# File ~/github/llmdh/notebooks/../llmdh/story_llms.py:337, in NovelLLM.gen_all(self, force, **kwargs)
#     335 for fn in lm.iter_progress(todo):
#     336     llm = self(filename=fn, force=force, **kwargs)
# --> 337     llm.save()
#     338     nap = random.randrange(5, 25)
#     339     if llm.result:
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:379, in LLM.save(self)
#     377 def save(self):
#     378     with self.get_db() as db:
# --> 379         if self.is_valid:
#     380             outd = {
#     381                 "model": self.model,
#     382                 "system_prompt": self.system_prompt,
#    (...)
#     388                 "is_valid": self.is_valid,
#     389             }
#     390             outkey = self.name
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:308, in LLM.is_valid(self)
#     306 @cached_property
#     307 def is_valid(self):
# --> 308     return self.parsed_response is not None
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File ~/github/llmdh/notebooks/../llmdh/story_llms.py:305, in NovelLLM.parsed_response(self)
#     303 @cached_property
#     304 def parsed_response(self):
# --> 305     res = self.response
#     306     try:
#     307         return dirty_jsonl_loads(res)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:363, in LLM.response(self)
#     361         if res:
#     362             return res
# --> 363 return self.gen()
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:296, in LLM.gen(self, verbose, max_tokens)
#     295 def gen(self, verbose=None, max_tokens=None):
# --> 296     return type(self).generate(
#     297         user_prompt=self.user_prompt,
#     298         system_prompt=self.system_prompt,
#     299         example_prompts=self.example_prompts,
#     300         model=self.model,
#     301         verbose=self.verbose if verbose is None else verbose,
#     302         max_tokens=self.max_tokens if max_tokens is None else max_tokens,
#     303         name=self.name,
#     304     )
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:89, in LLM.generate(cls, user_prompt, system_prompt, example_prompts, model, verbose, max_tokens, name, **kwargs)
#      78 kwargs = dict(
#      79     user_prompt=user_prompt if user_prompt else cls.user_prompt,
#      80     system_prompt=system_prompt if system_prompt else cls.system_prompt,
#    (...)
#      86     **kwargs,
#      87 )
#      88 if "gemini" in model:
# ---> 89     return cls.generate_gemini(**kwargs)
#      90 elif "gpt" in model:
#      91     return cls.generate_openai(**kwargs)
#
# File ~/github/llmdh/notebooks/../llmdh/llms.py:214, in LLM.generate_gemini(cls, user_prompt, model, verbose, name, temp, *args, **kwargs)
#     211     lm.log(f"PROMPT: {prompt}")
#     212 try:
#     213     # res = gemini_api().generate_content(prompt)
# --> 214     res = cls.gemini_api(model=model).generate_content(
#     215         prompt,
#     216         generation_config=GenerationConfig(
#     217             max_output_tokens=None,
#     218             temperature=temp,
#     219         ),
#     220         safety_settings={
#     221             HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
#     222             HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
#     223             HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
#     224             HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
#     225         },
#     226         request_options={"timeout": 600},
#     227     )
#     229     text = "\n\n".join(
#     230         part.text for part in res.parts if hasattr(part, "text")
#     231     )
#     232     if verbose:
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/generativeai/generative_models.py:262, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     260         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     261     else:
# --> 262         response = self._client.generate_content(
#     263             request,
#     264             **request_options,
#     265         )
#     266         return generation_types.GenerateContentResponse.from_response(response)
#     267 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:812, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     809 self._validate_universe_domain()
#     811 # Send the request.
# --> 812 response = rpc(
#     813     request,
#     814     retry=retry,
#     815     timeout=timeout,
#     816     metadata=metadata,
#     817 )
#     819 # Done; return the response.
#     820 return response
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/grpc/_channel.py:1173, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def __call__(
#    1162     self,
#    1163     request: Any,
#    (...)
#    1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Any:
#    1170     (
#    1171         state,
#    1172         call,
# -> 1173     ) = self._blocking(
#    1174         request, timeout, metadata, credentials, wait_for_ready, compression
#    1175     )
#    1176     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/github/llmdh/venv/lib/python3.12/site-packages/grpc/_channel.py:1157, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1141 state.target = _common.decode(self._target)
#    1142 call = self._channel.segregated_call(
#    1143     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1144     self._method,
#    (...)
#    1155     self._context,
#    1156 )
# -> 1157 event = call.next_event()
#    1158 _handle_event(event, state, self._response_deserializer)
#    1159 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:367, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:188, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:182, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
# llm = NovelRelationshipsLLM(filename='chadwyck.Eliot.Middlemarch_A_Study_of_Pr.1192.txt')
# llm = NovelRelationshipsLLM(filename='chadwyck.Austen.Emma_A_Novel_In_Three_Vol.1090.txt')
# llm = NovelRelationshipsLLM(filename='chadwyck.Austen.Sense_and_Sensibility_A_N.1097.txt')
llm = NovelRelationshipsLLM(filename='chadwyck.Austen.Pride_and_Prejudice_A_Nov.1095.txt')
llm = NovelRelationshipsLLM(filename='chadwyck.Austen.Northanger_Abbey_and_Pers.1093.txt')
# llm = NovelRelationshipsLLM(filename='chadwyck.Burney.Evelina.1008.txt')
# llm = NovelRelationshipsLLM(filename='chadwyck.Dickens.Bleak_House_By_Charles_Di.1168.txt')
# llm = NovelRelationshipsLLM(filename='Richardson.Pamela.txt')
# llm = NovelRelationshipsLLM(filename='chadwyck.Haywood.Betsy_Thoughtless.1038.txt')
# llm.result
llm.plot_network()

# %%
# pd.DataFrame(llm.result)
pprint(llm.result[-3])

# %%
llm.result
