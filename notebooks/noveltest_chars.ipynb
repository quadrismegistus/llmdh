# %%
import sys
sys.path.insert(0,'..')
from llmdh.story_llms import *

# %%
list(NovelCharactersLLM.db.keys())
# Out:
# ['chadwyck.Defoe.Moll_Flanders.1021.txt',
#  'chadwyck.Spofford.NewEngland_Legends_a_mach.0765.txt',
#  'chadwyck.Ballantyne.The_Coral_Island_A_Tale_o.1134.txt',
#  'chadwyck.Meredith.One_of_Our_Conquerors_By.1241.txt',
#  'chadwyck.Brown.The_Novels_a_machinereada.0075.txt',
#  'chadwyck.Sala.The_Seven_Sons_of_Mammon.1253.txt',
#  'chadwyck.Trollope.Phineas_Redux_By_Anthony.1286.txt',
#  'chadwyck.Lewis.The_Monk_A_Romance.1132.txt',
#  'chadwyck.Smith.The_Life_and_Writings_of.0756.txt',
#  'chadwyck.Irving.Tales_of_a_Traveller_volu.0482.txt']

# %%
NovelCharactersLLM.gen_all()
# Out:
# ⎾ parsing all novels @ 2024-05-19 09:45:58,903
# ￨ iterating:   0%|          | 0/1809 [00:00<?, ?it/s]Invalid control character at: line 27 column 833 (char 17616) @ 2024-05-19 09:51:10,337
# Invalid control character at: line 30 column 827 (char 17528) @ 2024-05-19 09:52:15,334
# ￨ failed on chadwyck.Willis.People_I_Have_Met_or_Pict.0876.txt. sleeping for 57s:   0%|          | 1/1809 [07:13<217:40:44, 433.43s/it]Invalid control character at: line 34 column 794 (char 7287) @ 2024-05-19 09:58:29,522
# Invalid control character at: line 40 column 788 (char 7179) @ 2024-05-19 09:59:29,351
# ￨ failed on chadwyck.Cooke.Leather_Stocking_and_Silk.0124.txt. sleeping for 54s:   0%|          | 2/1809 [14:24<216:50:46, 432.01s/it] Invalid control character at: line 106 column 356 (char 12073) @ 2024-05-19 10:01:42,824
# fixed by second request @ 2024-05-19 10:02:12,688
# ...
